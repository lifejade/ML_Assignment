# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import warnings
from scipy.stats import probplot
# %matplotlib inline

train = pd.read_csv('train1.csv')
test = pd.read_csv('test.csv')

#train[train.isna().sum(axis=1) > 0] # 결측치 확인

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# 1            40.0  159.0
# 2            19.0   26.0
# 3            64.0   57.0
# 4            11.0  431.0

# %%
test.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# 2            28.0
# 3            38.0
# 4            15.0

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# min              0.000000           7.000000            78.000000
# 25%              1.400000          36.000000           879.000000
# 50%              2.300000          51.000000          1577.000000
# 75%              3.400000          69.000000          1994.000000
# max              8.000000          99.000000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5        count
# count     1383.000000    1369.000000     1342.000000  1459.000000
# mean         0.039149      57.168736       30.327124   108.563400
# std          0.019509      31.771019       14.713252    82.631733
# min          0.003000       9.000000        8.000000     1.000000
# 25%          0.025500      36.000000       20.000000    37.000000
# 50%          0.039000      51.000000       26.000000    96.000000
# 75%          0.052000      69.000000       37.000000   150.000000
# max          0.125000     269.000000       90.000000   431.000000

# %%
test.describe()
# Out:
#                 id        hour  hour_bef_temperature  hour_bef_precipitation  \
# count   715.000000  715.000000            714.000000              714.000000
# mean   1056.854545   11.472727             23.263305                0.051821
# std     625.574471    6.928427              4.039645                0.221820
# min       0.000000    0.000000             14.600000                0.000000
# 25%     507.000000    5.500000             20.300000                0.000000
# 50%    1046.000000   11.000000             22.900000                0.000000
# 75%    1616.500000   17.000000             26.375000                0.000000
# max    2177.000000   23.000000             33.800000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count          714.000000         714.000000           714.000000
# mean             2.388515          56.668067          1359.494398
# std              1.171270          19.661880           614.171870
# min              0.000000          16.000000           126.000000
# 25%              1.500000          42.000000           807.250000
# 50%              2.300000          55.000000          1489.000000
# 75%              3.275000          73.750000          2000.000000
# max              5.900000         100.000000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# count      680.000000     678.000000      679.000000
# mean         0.041196      36.930678       24.939617
# std          0.020656      12.641503       10.075857
# min          0.003000       9.000000        7.000000
# 25%          0.027000      28.000000       17.000000
# 50%          0.039000      35.000000       24.000000
# 75%          0.052250      45.000000       31.000000
# max          0.138000      94.000000       69.000000

# %%
train.isnull().sum() # 결측치 확인
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
corrmat = train.corr(method='spearman')
indexes = corrmat.nlargest(n=11, columns='count').index
corrmat = train[indexes].corr(method='spearman')
sns.heatmap(data=corrmat, annot=True, cbar=True, fmt='.2f', ax=ax)
# Out:
# <Axes: >

# %%
# 종속변수 count 시각화
data = train['count']
fig, ax = plt.subplots(1, 1, figsize=(6,6))
probplot(data, plot=ax)
plt.show()

# %%
data = np.power(train['count'], 1/3)
fig, ax = plt.subplots(1,1,figsize=(12,6))
probplot(data, plot=ax)
plt.show()

# %%
# 독립변수 hour 시각화
# train data
fig, axes = plt.subplots(1, 2, figsize=(12,6))
sns.histplot(train['hour'], ax=axes[0])
sns.regplot(data=train, x='hour', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour', ylabel='count'>

# %%
# test data
fig, axes = plt.subplots(1, 1, figsize=(6,6))
sns.histplot(test['hour'], ax=axes)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour', ylabel='Count'>

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))
sns.boxplot(data=train, x='hour', y='count')
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
# temperature 시각화
# train data
data = train.copy()
fig, axes = plt.subplots(1, 2, figsize=(12,6))
sns.histplot(data['hour_bef_temperature'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_temperature', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_temperature', ylabel='count'>

# %%
# test data
data = test.copy()
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.histplot(data['hour_bef_temperature'], ax=ax)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_temperature', ylabel='Count'>

# %%
# visibility 시각화
# train data
data = train.copy()
data['hour_bef_visibility'] = np.power(data['hour_bef_visibility'], 3)
data['hour_bef_visibility'] /= np.max(data['hour_bef_visibility'])
fig, axes = plt.subplots(1, 2, figsize=(12,6))
sns.histplot(data['hour_bef_visibility'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_visibility', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_visibility', ylabel='count'>

# %%
def set_visibility(x):
    if x > 0.8:
        return 2
    elif x > 0.36:
        return 1
    else:
        return 0

# %%
data['visibility'] = data['hour_bef_visibility'].map(set_visibility)

# %%
data.groupby('visibility')['count'].mean()
# Out:
# visibility
# 0     86.265672
# 1    109.484716
# 2    134.864286
# Name: count, dtype: float64

# %%
# windspeed 시각화
# train data
data = train.copy()
data['hour_bef_windspeed'] = np.power(data['hour_bef_windspeed'], 1/2)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
sns.histplot(data['hour_bef_windspeed'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_windspeed', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_windspeed', ylabel='count'>

# %%
# test data
data = test.copy()
data['hour_bef_windspeed'] = np.power(data['hour_bef_windspeed'], 1/2)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
sns.histplot(data['hour_bef_windspeed'], ax=axes)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_windspeed', ylabel='Count'>

# %%
# hubidity 시각화
# train data
data = train.copy()
# data['hour_bef_humidity'] = (data['hour_bef_humidity'] - np.mean(data['hour_bef_humidity'])) / np.std(data['hour_bef_humidity'])
data['count'] = np.power(data['count'], 1/3)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
sns.histplot(data['hour_bef_humidity'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_humidity', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_humidity', ylabel='count'>

# %%
# test data
data = test.copy()
data['hour_bef_humidity'] = (data['hour_bef_humidity'] - np.mean(data['hour_bef_humidity'])) / np.std(data['hour_bef_humidity'])
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
sns.histplot(data['hour_bef_humidity'], ax=axes)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_humidity', ylabel='Count'>

# %%
# ozone 시각화
# train data
data = train.copy()
data['hour_bef_ozone'] = np.power(data['hour_bef_ozone'], 1/2)
data['count'] = np.power(data['count'], 1/3)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
sns.histplot(data['hour_bef_ozone'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_ozone', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_ozone', ylabel='count'>

# %%
# 미세먼지 시각화
# train data
data = train.copy()
data['hour_bef_pm10'] = np.log1p(data['hour_bef_pm10'])
data['count'] = np.power(data['count'], 1/3)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
sns.histplot(data['hour_bef_pm10'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_pm10', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_pm10', ylabel='count'>

# %%
data = train.copy()
data['hour_bef_pm2.5'] =  np.log1p(data['hour_bef_pm2.5'])
data['count'] = np.power(data['count'], 1/3)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
sns.histplot(data['hour_bef_pm2.5'], ax=axes[0])
sns.regplot(data=data, x='hour_bef_pm2.5', y='count', ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hour_bef_pm2.5', ylabel='count'>

# %%
# 전처리

# %%
# precipitation

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      715 non-null    int64
#  1   hour                    715 non-null    int64
#  2   hour_bef_temperature    714 non-null    float64
#  3   hour_bef_precipitation  714 non-null    float64
#  4   hour_bef_windspeed      714 non-null    float64
#  5   hour_bef_humidity       714 non-null    float64
#  6   hour_bef_visibility     714 non-null    float64
#  7   hour_bef_ozone          680 non-null    float64
#  8   hour_bef_pm10           678 non-null    float64
#  9   hour_bef_pm2.5          679 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 56.0 KB

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %%
train[train['hour_bef_precipitation'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
# hour_bef_precipitation 가 Nan인 값 처리

# %%
fill_value = train[train['count'] == 1].mean()

# %%
train.iloc[934, 2:-1] = fill_value.iloc[2:-1]

# %%
fill_value = train[train['count'] == 39].mean()

# %%
train.iloc[1035, 2:-1] = fill_value.iloc[2:-1]

# %%
# 결측치 처리 확인
train[(train['id'] == 1420) | (train['id'] == 1553)]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0             12.000000                0.833333
# 1035  1553    18             14.066667                0.203704
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934             3.383333          89.166667           661.833333
# 1035            1.709259          71.574074          1076.092593
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934         0.034167      32.500000       27.200000   39.0
# 1035        0.031861      70.583333       34.366667    1.0

# %%
#test data 결측치 처리
test[test.isna().sum(axis=1) > 1]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18     42    18                  29.4                     0.0
# 32     82     1                  22.8                     0.0
# 40    115     1                  21.5                     1.0
# 47    147     1                  22.8                     0.0
# 86    260     1                  20.0                     0.0
# 92    270     1                  20.0                     0.0
# 102   297     1                  15.1                     1.0
# 114   323     1                  18.7                     0.0
# 126   352     1                  19.2                     0.0
# 128   356    15                  25.5                     0.0
# 129   358     1                  23.6                     0.0
# 137   391    15                  29.0                     0.0
# 209   609     1                  18.6                     0.0
# 223   643     1                  16.8                     0.0
# 237   675    19                  29.0                     0.0
# 272   781     1                  20.1                     0.0
# 307   890     1                  20.9                     0.0
# 353  1034     1                  23.7                     0.0
# 355  1040     1                  24.7                     0.0
# 360  1050     1                  19.5                     0.0
# 393  1143     1                  21.7                     0.0
# 418  1236     1                  21.6                     0.0
# 419  1237     1                  18.8                     0.0
# 458  1356     1                  23.2                     0.0
# 471  1395     1                  21.4                     0.0
# 492  1462     1                  20.9                     0.0
# 502  1512     1                  21.4                     0.0
# 523  1574     1                  19.5                     0.0
# 571  1712    16                  25.5                     0.0
# 620  1857     1                  21.2                     0.0
# 626  1871     1                  22.9                     0.0
# 642  1913     1                  24.6                     0.0
# 653  1943    19                   NaN                     NaN
# 694  2104     1                  21.7                     0.0
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                  3.3               43.0               1685.0
# 32                  2.4               52.0               2000.0
# 40                  0.5               90.0                347.0
# 47                  1.2               57.0               1190.0
# 86                  2.0               65.0               1662.0
# 92                  1.7               31.0               2000.0
# 102                 2.2               98.0                224.0
# 114                 1.4               41.0               2000.0
# 126                 1.4               80.0               1085.0
# 128                 3.6               40.0               1404.0
# 129                 0.9               83.0                466.0
# 137                 2.9               49.0               1776.0
# 209                 2.4               37.0               2000.0
# 223                 3.6               83.0               1839.0
# 237                 4.0               38.0               1959.0
# 272                 3.1               81.0                266.0
# 307                 0.4               73.0               1218.0
# 353                 2.0               78.0                332.0
# 355                 1.7               48.0               1864.0
# 360                 2.6               42.0               2000.0
# 393                 2.8               77.0               1829.0
# 418                 2.6               81.0               1340.0
# 419                 0.9               72.0                503.0
# 458                 1.5               65.0               1734.0
# 471                 1.8               74.0               1300.0
# 492                 2.5               41.0               2000.0
# 502                 1.1               73.0                713.0
# 523                 2.6               77.0                769.0
# 571                 4.6               45.0               1320.0
# 620                 1.6               68.0                839.0
# 626                 2.6               38.0               2000.0
# 642                 0.6               55.0               2000.0
# 653                 NaN                NaN                  NaN
# 694                 1.7               75.0                957.0
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 18            0.055            NaN             NaN
# 32              NaN            NaN             NaN
# 40              NaN            NaN             NaN
# 47              NaN            NaN             NaN
# 86              NaN            NaN             NaN
# 92              NaN            NaN             NaN
# 102             NaN            NaN             NaN
# 114             NaN            NaN             NaN
# 126             NaN            NaN             NaN
# 128           0.077            NaN             NaN
# 129             NaN            NaN             NaN
# 137           0.052            NaN             NaN
# 209             NaN            NaN             NaN
# 223             NaN            NaN             NaN
# 237           0.053            NaN             NaN
# 272             NaN            NaN             NaN
# 307             NaN            NaN             NaN
# 353             NaN            NaN             NaN
# 355             NaN            NaN             NaN
# 360             NaN            NaN             NaN
# 393             NaN            NaN             NaN
# 418             NaN            NaN             NaN
# 419             NaN            NaN             NaN
# 458             NaN            NaN             NaN
# 471             NaN            NaN             NaN
# 492             NaN            NaN             NaN
# 502             NaN            NaN             NaN
# 523             NaN            NaN             NaN
# 571           0.082            NaN             NaN
# 620             NaN            NaN             NaN
# 626             NaN            NaN             NaN
# 642             NaN            NaN             NaN
# 653             NaN            NaN             NaN
# 694             NaN            NaN             NaN
# 710             NaN            NaN             NaN
# 711             NaN            NaN             NaN

# %%
# index 653번 처리
test.iloc[653, 2:] = fill_value[2:-1]

# %%
test[test.isna().sum(axis=1) > 1]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18     42    18                  29.4                     0.0
# 32     82     1                  22.8                     0.0
# 40    115     1                  21.5                     1.0
# 47    147     1                  22.8                     0.0
# 86    260     1                  20.0                     0.0
# 92    270     1                  20.0                     0.0
# 102   297     1                  15.1                     1.0
# 114   323     1                  18.7                     0.0
# 126   352     1                  19.2                     0.0
# 128   356    15                  25.5                     0.0
# 129   358     1                  23.6                     0.0
# 137   391    15                  29.0                     0.0
# 209   609     1                  18.6                     0.0
# 223   643     1                  16.8                     0.0
# 237   675    19                  29.0                     0.0
# 272   781     1                  20.1                     0.0
# 307   890     1                  20.9                     0.0
# 353  1034     1                  23.7                     0.0
# 355  1040     1                  24.7                     0.0
# 360  1050     1                  19.5                     0.0
# 393  1143     1                  21.7                     0.0
# 418  1236     1                  21.6                     0.0
# 419  1237     1                  18.8                     0.0
# 458  1356     1                  23.2                     0.0
# 471  1395     1                  21.4                     0.0
# 492  1462     1                  20.9                     0.0
# 502  1512     1                  21.4                     0.0
# 523  1574     1                  19.5                     0.0
# 571  1712    16                  25.5                     0.0
# 620  1857     1                  21.2                     0.0
# 626  1871     1                  22.9                     0.0
# 642  1913     1                  24.6                     0.0
# 694  2104     1                  21.7                     0.0
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                  3.3               43.0               1685.0
# 32                  2.4               52.0               2000.0
# 40                  0.5               90.0                347.0
# 47                  1.2               57.0               1190.0
# 86                  2.0               65.0               1662.0
# 92                  1.7               31.0               2000.0
# 102                 2.2               98.0                224.0
# 114                 1.4               41.0               2000.0
# 126                 1.4               80.0               1085.0
# 128                 3.6               40.0               1404.0
# 129                 0.9               83.0                466.0
# 137                 2.9               49.0               1776.0
# 209                 2.4               37.0               2000.0
# 223                 3.6               83.0               1839.0
# 237                 4.0               38.0               1959.0
# 272                 3.1               81.0                266.0
# 307                 0.4               73.0               1218.0
# 353                 2.0               78.0                332.0
# 355                 1.7               48.0               1864.0
# 360                 2.6               42.0               2000.0
# 393                 2.8               77.0               1829.0
# 418                 2.6               81.0               1340.0
# 419                 0.9               72.0                503.0
# 458                 1.5               65.0               1734.0
# 471                 1.8               74.0               1300.0
# 492                 2.5               41.0               2000.0
# 502                 1.1               73.0                713.0
# 523                 2.6               77.0                769.0
# 571                 4.6               45.0               1320.0
# 620                 1.6               68.0                839.0
# 626                 2.6               38.0               2000.0
# 642                 0.6               55.0               2000.0
# 694                 1.7               75.0                957.0
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 18            0.055            NaN             NaN
# 32              NaN            NaN             NaN
# 40              NaN            NaN             NaN
# 47              NaN            NaN             NaN
# 86              NaN            NaN             NaN
# 92              NaN            NaN             NaN
# 102             NaN            NaN             NaN
# 114             NaN            NaN             NaN
# 126             NaN            NaN             NaN
# 128           0.077            NaN             NaN
# 129             NaN            NaN             NaN
# 137           0.052            NaN             NaN
# 209             NaN            NaN             NaN
# 223             NaN            NaN             NaN
# 237           0.053            NaN             NaN
# 272             NaN            NaN             NaN
# 307             NaN            NaN             NaN
# 353             NaN            NaN             NaN
# 355             NaN            NaN             NaN
# 360             NaN            NaN             NaN
# 393             NaN            NaN             NaN
# 418             NaN            NaN             NaN
# 419             NaN            NaN             NaN
# 458             NaN            NaN             NaN
# 471             NaN            NaN             NaN
# 492             NaN            NaN             NaN
# 502             NaN            NaN             NaN
# 523             NaN            NaN             NaN
# 571           0.082            NaN             NaN
# 620             NaN            NaN             NaN
# 626             NaN            NaN             NaN
# 642             NaN            NaN             NaN
# 694             NaN            NaN             NaN
# 710             NaN            NaN             NaN
# 711             NaN            NaN             NaN

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          7
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone             74
# hour_bef_pm10              88
# hour_bef_pm2.5            115
# count                       0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       0
# hour_bef_precipitation     0
# hour_bef_windspeed         0
# hour_bef_humidity          0
# hour_bef_visibility        0
# hour_bef_ozone            34
# hour_bef_pm10             36
# hour_bef_pm2.5            35
# dtype: int64

# %%
# 결측치 처리(훈련데이터)
fill_data = train.groupby('hour_bef_precipitation').mean()

# %%
fill_data
# Out:
#                                  id       hour  hour_bef_temperature  \
# hour_bef_precipitation
# 0.000000                1111.806520  11.469880             16.809213
# 0.203704                1553.000000  18.000000             14.066667
# 0.833333                1420.000000   0.000000             12.000000
# 1.000000                 908.630435  12.326087             13.902174
#
#                         hour_bef_windspeed  hour_bef_humidity  \
# hour_bef_precipitation
# 0.000000                          2.473362          51.214741
# 0.203704                          1.709259          71.574074
# 0.833333                          3.383333          89.166667
# 1.000000                          2.652174          83.413043
#
#                         hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# hour_bef_precipitation
# 0.000000                        1428.072998        0.039367      57.454819
# 0.203704                        1076.092593        0.031861      70.583333
# 0.833333                         661.833333        0.034167      32.500000
# 1.000000                         704.130435        0.032349      47.902439
#
#                         hour_bef_pm2.5       count
# hour_bef_precipitation
# 0.000000                     30.314900  111.130404
# 0.203704                     34.366667    1.000000
# 0.833333                     27.200000   39.000000
# 1.000000                     30.725000   33.673913

# %%
null_columns = ['hour_bef_windspeed', 'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5']

# %%
# 결측치 채우기
for c in null_columns:
    train[c][train['hour_bef_precipitation']==0] = train[c][train['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
    train[c][train['hour_bef_precipitation']==1] = train[c][train['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
    test[c][test['hour_bef_precipitation']==0] = test[c][test['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
    test[c][test['hour_bef_precipitation']==1] = test[c][test['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# Out:
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==0] = train[c][train['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==1] = train[c][train['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==0] = test[c][test['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==1] = test[c][test['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==0] = train[c][train['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==1] = train[c][train['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==0] = test[c][test['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==1] = test[c][test['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==0] = train[c][train['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==1] = train[c][train['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==0] = test[c][test['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==1] = test[c][test['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==0] = train[c][train['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[c][train['hour_bef_precipitation']==1] = train[c][train['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==0] = test[c][test['hour_bef_precipitation']==0].fillna(fill_data[c].iloc[0], axis=0)
# /var/folders/34/n7y7n8qx645g3fj3l1c7q2zr0000gp/T/ipykernel_62816/3283935086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[c][test['hour_bef_precipitation']==1] = test[c][test['hour_bef_precipitation']==1].fillna(fill_data[c].iloc[1], axis=0)

# %%
# 확인
train.isnull().sum(), test.isnull().sum()
# Out:
# (id                        0
#  hour                      0
#  hour_bef_temperature      0
#  hour_bef_precipitation    0
#  hour_bef_windspeed        0
#  hour_bef_humidity         0
#  hour_bef_visibility       0
#  hour_bef_ozone            0
#  hour_bef_pm10             0
#  hour_bef_pm2.5            0
#  count                     0
#  dtype: int64,
#  id                        0
#  hour                      0
#  hour_bef_temperature      0
#  hour_bef_precipitation    0
#  hour_bef_windspeed        0
#  hour_bef_humidity         0
#  hour_bef_visibility       0
#  hour_bef_ozone            0
#  hour_bef_pm10             0
#  hour_bef_pm2.5            0
#  dtype: int64)

# %%
train[train.isna().sum(axis=1) > 1]
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []

# %%
# 목적변수 재표현 (1/3 제곱으로 변환)
data = np.power(train['count'], 1/3)
train['count'] = data

# %%
# 가시성 부분 세구간으로 나누기

data = train.copy()
data['hour_bef_visibility'] = np.power(data['hour_bef_visibility'], 3)
data['hour_bef_visibility'] /= np.max(data['hour_bef_visibility'])
data['visibility'] = data['hour_bef_visibility'].map(set_visibility)

# %%
data['visibility'].value_counts()
# Out:
# visibility
# 0    670
# 2    560
# 1    229
# Name: count, dtype: int64

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5     count
# 0              0.027           76.0            33.0  3.659306
# 1              0.042           73.0            40.0  5.417502
# 2              0.033           32.0            19.0  2.962496
# 3              0.040           75.0            64.0  3.848501
# 4              0.057           27.0            11.0  7.553689
# ...              ...            ...             ...       ...
# 1454           0.031           37.0            27.0  2.758924
# 1455           0.039           34.0            19.0  2.714418
# 1456           0.009           30.0            21.0  2.802039
# 1457           0.082           71.0            36.0  6.000000
# 1458           0.046           38.0            17.0  5.539658
#
# [1459 rows x 11 columns]

# %%
#train['visibility'] = data['visibility']
train['hour_bef_visibility'] = data['visibility']

# %%
data = test.copy()
data['hour_bef_visibility'] = np.power(data['hour_bef_visibility'], 3)
data['hour_bef_visibility'] /= np.max(data['hour_bef_visibility'])
data['visibility'] = data['hour_bef_visibility'].map(set_visibility)

# %%
data['visibility'].value_counts()
# Out:
# visibility
# 0    350
# 2    262
# 1    103
# Name: count, dtype: int64

# %%
#test['visibility'] = data['visibility']
test['hour_bef_visibility'] = data['visibility']

# %%
# 풍속, 오존, 미세먼지 재표현

# %%
train['hour_bef_windspeed'] = np.power(train['hour_bef_windspeed'], 1/2)
test['hour_bef_windspeed'] = np.power(test['hour_bef_windspeed'], 1/2)

# %%
train['hour_bef_ozone'] = np.power(train['hour_bef_ozone'], 1/2)
test['hour_bef_ozone'] = np.power(test['hour_bef_ozone'], 1/2)

# %%
train['hour_bef_pm10'] = np.power(train['hour_bef_pm10'], 1/2)
test['hour_bef_pm10'] = np.power(test['hour_bef_pm10'], 1/2)

# %%
train['hour_bef_pm2.5'] = np.power(train['hour_bef_pm2.5'], 1/2)
test['hour_bef_pm2.5'] = np.power(test['hour_bef_pm2.5'], 1/2)

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0               1.224745               89.0                    0
# 1               1.183216               48.0                    0
# 2               0.836660               79.0                    0
# 3               1.643168               54.0                    0
# 4               2.190890                7.0                    2
# ...                  ...                ...                  ...
# 1454            1.264911               53.0                    2
# 1455            1.949359               45.0                    2
# 1456            1.378405               54.0                    2
# 1457            1.923538               37.0                    0
# 1458            1.760682               47.0                    2
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5     count
# 0           0.164317       8.717798        5.744563  3.659306
# 1           0.204939       8.544004        6.324555  5.417502
# 2           0.181659       5.656854        4.358899  2.962496
# 3           0.200000       8.660254        8.000000  3.848501
# 4           0.238747       5.196152        3.316625  7.553689
# ...              ...            ...             ...       ...
# 1454        0.176068       6.082763        5.196152  2.758924
# 1455        0.197484       5.830952        4.358899  2.714418
# 1456        0.094868       5.477226        4.582576  2.802039
# 1457        0.286356       8.426150        6.000000  6.000000
# 1458        0.214476       6.164414        4.123106  5.539658
#
# [1459 rows x 11 columns]

# %%
test
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       0     7                  20.7                     0.0
# 1       1    17                  30.0                     0.0
# 2       2    13                  19.0                     1.0
# 3       4     6                  22.5                     0.0
# 4       5    22                  14.6                     1.0
# ..    ...   ...                   ...                     ...
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0              1.140175               62.0                    0
# 1              2.323790               33.0                    1
# 2              1.449138               95.0                    0
# 3              1.581139               60.0                    0
# 4              1.843909               93.0                    0
# ..                  ...                ...                  ...
# 710            1.549193               60.0                    1
# 711            1.000000               55.0                    2
# 712            1.516575               66.0                    1
# 713            1.264911               46.0                    2
# 714            1.000000               63.0                    0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 0          0.202485       6.633250        5.196152
# 1          0.246982       7.000000        6.000000
# 2          0.141421       6.000000        5.291503
# 3          0.164317       7.211103        6.164414
# 4          0.202485       4.242641        3.872983
# ..              ...            ...             ...
# 710        0.198412       7.579896        5.505897
# 711        0.198412       7.579896        5.505897
# 712        0.141421       4.123106        3.872983
# 713        0.178885       6.324555        5.099020
# 714        0.083666       5.477226        4.898979
#
# [715 rows x 10 columns]

# %%
# 필요없는 특성 버리기

# %%
drop_columns = ['id']

# %%
train = train.drop(columns=drop_columns, axis=1)
test = test.drop(columns=drop_columns, axis=1)

# %%
train.drop('count', axis=1)
# Out:
#       hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0       20                  16.3                     1.0            1.224745
# 1       13                  20.1                     0.0            1.183216
# 2        6                  13.9                     0.0            0.836660
# 3       23                   8.1                     0.0            1.643168
# 4       18                  29.5                     0.0            2.190890
# ...    ...                   ...                     ...                 ...
# 1454     4                  16.8                     0.0            1.264911
# 1455     3                  10.8                     0.0            1.949359
# 1456     5                  18.3                     0.0            1.378405
# 1457    21                  20.7                     0.0            1.923538
# 1458    17                  21.1                     0.0            1.760682
#
#       hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0                  89.0                    0        0.164317       8.717798
# 1                  48.0                    0        0.204939       8.544004
# 2                  79.0                    0        0.181659       5.656854
# 3                  54.0                    0        0.200000       8.660254
# 4                   7.0                    2        0.238747       5.196152
# ...                 ...                  ...             ...            ...
# 1454               53.0                    2        0.176068       6.082763
# 1455               45.0                    2        0.197484       5.830952
# 1456               54.0                    2        0.094868       5.477226
# 1457               37.0                    0        0.286356       8.426150
# 1458               47.0                    2        0.214476       6.164414
#
#       hour_bef_pm2.5
# 0           5.744563
# 1           6.324555
# 2           4.358899
# 3           8.000000
# 4           3.316625
# ...              ...
# 1454        5.196152
# 1455        4.358899
# 1456        4.582576
# 1457        6.000000
# 1458        4.123106
#
# [1459 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

X_train = train.drop('count', axis=1).values
y_train = train['count'].values

X_test = test.values

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)

#print(y_test.shape)
# Out:
# (1459, 9)
# (715, 9)
# (1459,)

# %%
# 정규화
"""
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)
"""
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\nscaler.fit(X_train)\nX_train_std = scaler.transform(X_train)\nX_test_std = scaler.transform(X_test)\n'

# %%
#X_train_std # = X_train

# %%
#X_test_std # = X_test

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.001)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
print(lasso.score(X_train, y_train))
print("사용한 특성의 수 : {}".format(np.sum(lasso.coef_ != 0)))
# Out:
# 0.6304345211210243
# 사용한 특성의 수 : 8

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.01)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.01)

# %%
print(ridge.score(X_train, y_train))
print("사용한 특성의 수 : {}".format(np.sum(ridge.coef_ != 0)))
# Out:
# 0.6306010314911841
# 사용한 특성의 수 : 9

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.score(X_train, y_train))
# Out:
# 0.6306010358770369
